# %%
import pandas as pd
import numpy as np
from IPython.display import HTML

# from __future__ import print_function)
import keras
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, RNN, SimpleRNNCell, SimpleRNN
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
# !wget https://raw.githubusercontent.com/EliotAndres/char-rnn-tensorflow-js/master/python/companies.csv

# %%
companies = pd.read_csv('./companies.csv', header=None)
companies.head()
# Out:
#                     0
# 0       Hashplay Inc.
# 1      New Incentives
# 2            GrabJobs
# 3           MediBookr
# 4  MelissaWithLove.co

# %%
names = companies[0].values
text = '\n'.join(names)

chars = sorted(list(set(text)))
print('total chars: {}'.format(len(chars)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 150

# %%
print('Corpus length:', len(text), 'lines:', len(names))
print('First 10 lines:', names[:10])
print('Number of unique chars:', len(chars))
# Out:
# Corpus length: 2560407 lines: 172488
# First 10 lines: ['Hashplay Inc.' 'New Incentives' 'GrabJobs' 'MediBookr'
#  'MelissaWithLove.co' 'Starting 11' 'The CarShare Guy' 'Allahabad Bank'
#  'Anlaiye' 'Any Time Loan']
# Number of unique chars: 150

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 10
step = 3

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
print('First 10 sequences and next chars:')
for i in range(10):
    print('[{}]:[{}]'.format(sentences[i], next_chars[i]))
# Out:
# Number of sequences: 853466
# First 10 sequences and next chars:
# [Hashplay I]:[n]
# [hplay Inc.]:[
# ]
# [ay Inc.
# Ne]:[w]
# [Inc.
# New I]:[n]
# [.
# New Ince]:[n]
# [ew Incenti]:[v]
# [Incentives]:[
# ]
# [entives
# Gr]:[a]
# [ives
# GrabJ]:[o]
# [s
# GrabJobs]:[
# ]

# %%
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Size of X: {:.2f} MB'.format(X.nbytes/1024/1024))
print('Size of y: {:.2f} MB'.format(y.nbytes/1024/1024))
# Out:
# Vectorization...
# Size of X: 1220.89 MB
# Size of y: 122.09 MB

# %%
# ### Initialization
# 
# Now we are ready to create a recurrent model.  Keras contains three types of recurrent layers:
# 
#  * `SimpleRNN`, a fully-connected RNN where the output is fed back to input.
#  * `LSTM`, the Long-Short Term Memory unit layer.
#  * `GRU`, the Gated Recurrent Unit layer.
# 
# See https://keras.io/layers/recurrent/ for more information.

# Number of hidden units to use:
nb_units = 64

model = Sequential()

# Recurrent layers supported: SimpleRNN, LSTM, GRU:
model.add(LSTM(nb_units, input_shape=(maxlen, len(chars))))

# To stack multiple RNN layers, all RNN layers except the last one need
# to have "return_sequences=True".  An example of using two RNN layers:
#model.add(SimpleRNN(16,
#                    input_shape=(maxlen, len(chars)),
#                    return_sequences=True))
#model.add(SimpleRNN(32))

model.add(Dense(units=len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

print(model.summary())
# Out:
# WARNING:tensorflow:From c:\users\loukik\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 64)                55040
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               9750
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# =================================================================
# Total params: 64,790
# Trainable params: 64,790
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
class SampleResult(keras.callbacks.Callback):

    def on_epoch_end(self, epoch, logs={}):

        start_index = random.randint(0, len(text) - maxlen - 1)

        for diversity in [0.2, 0.5, 1.0, 1.2]:
            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print()
            print('----- Generating with diversity',
                  diversity, 'seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(100):
                x = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x[0, t, char_indices[char]] = 1.

                preds = self.model.predict(x, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
        print('\n\n')
sample_callback = SampleResult()

# %%
history = model.fit(X, y, 
                        epochs=10, 
                        batch_size=512,
                        verbose=2,
                       callbacks=[sample_callback])
# Out:
# WARNING:tensorflow:From c:\users\loukik\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
#  - 64s - loss: 2.2657
#
# ----- Generating with diversity 0.2 seed: " Inc.
# Zomb"
#  Inc.
# Zombre
# Energy Communications
# Transer Solutions
# Management
# Arter Solutions
# Starter Technology
# The South S
# ----- Generating with diversity 0.5 seed: " Inc.
# Zomb"
#  Inc.
# Zombadit
# Servister
# Pactors
# Tradel Holdings
# Lupentering
# Networks
# Shanger Media
# Managems Biotech
# Argental
#
# ----- Generating with diversity 1.0 seed: " Inc.
# Zomb"
#  Inc.
# Zombom.num Systems
# Kapo Droustire
# Anishyant
# UPBour
# Serazeatr
# R.cald
# Actaration Casing Group
# Adcanei Comp
# ----- Generating with diversity 1.2 seed: " Inc.
# Zomb"
#  Inc.
# Zombrama Accemrixa
# Paradsaranet Limited
# Nagguria BT LLC Energynts Group
# Prilk
# CIVR
# Sign
# Grade.on
# Trubjex
#
#
# Epoch 2/10
#  - 60s - loss: 2.0143
#
# ----- Generating with diversity 0.2 seed: "t
# BrickVes"
# t
# BrickVest Services
# Share Stedio
# Spectron Services
# The Medical
# Bank Services
# Starth Medical
# Sentar Services
# T
# ----- Generating with diversity 0.5 seed: "t
# BrickVes"
# t
# BrickVesion
# Sension
# Streetrand Communications
# Silective Corp
# Convett Solutions
# Transource
# International Corp
# ----- Generating with diversity 1.0 seed: "t
# BrickVes"
# t
# BrickVes
# Lamita Technology
# Like Haurk
# NiVixa Consultyno Allsabe
# Dishor Group
# Nioinale Scyment
# Blirble Medaco
# ----- Generating with diversity 1.2 seed: "t
# BrickVes"
# t
# BrickVesitar Enterprisior Graun
# Care
# qui
# hokSta
# BubFagiz
# Ru
# AquyMap
# Ibricker
# VewAuptiCar
# m-Centy Systems Net
#
#
# Epoch 3/10
#  - 57s - loss: 1.9678
#
# ----- Generating with diversity 0.2 seed: "
# Rachel Jo"
#
# Rachel Jousine Solution
# Super Solution
# Media Corporation
# Alliance Group
# Contech Solution
# Aller Solution
# Allia
# ----- Generating with diversity 0.5 seed: "
# Rachel Jo"
#
# Rachel Jops
# Stoneware
# Home Benterial Corporation
# Bathhetters Industries
# Sundare Inc.
# Hardsist
# Health Investor
# ----- Generating with diversity 1.0 seed: "
# Rachel Jo"
#
# Rachel Josen
# Angro.com
# Aomis Group
# Servie Inc
# Stove Mobyle PowerLites
# KioCorn
# Kainovotpits
# Franser Soluity
# Sa
# ----- Generating with diversity 1.2 seed: "
# Rachel Jo"
#
# Rachel Jouff Clescot
# AhimGent Wind.
# GotteWril
# Allia Partnors
# EurofurÕs Olthhipsportls Fre Inturts
# Lisiu
# Keren
#
#
# Epoch 4/10
#  - 55s - loss: 1.9438
#
# ----- Generating with diversity 0.2 seed: "Technology"
# Technology
# Allier Solutions
# Alliance
# Accelland Systems
# Carestreet
# Controlite
# Allier Medical
# Solution Services
#
# ----- Generating with diversity 0.5 seed: "Technology"
# Technology
# Allied Solutions
# Mariner Systems
# Cord Services
# Accet Inc
# Cardince Corporation
# Pinero
# Care
# Compans M
# ----- Generating with diversity 1.0 seed: "Technology"
# Technology
# Supermedica Buy8 Development
# espatet Viderancese
# Vasib
# Ooneele Gitter
# ModiDiacers
# Outued Nati Techn
# ----- Generating with diversity 1.2 seed: "Technology"
# Technology
# Coeme TloluMabD
# Wokros
# Puaner Capital Digital
# Fandage Ltd.
# GoGass4Yon Shapies
# FiNOe Micro Group Inc
#
#
# Epoch 5/10
#  - 54s - loss: 1.9286
#
# ----- Generating with diversity 0.2 seed: "ektrona
# Bu"
# ektrona
# Bure Star
# Contine Solutions
# Stream Services
# Allin Startheral Communications
# Corporate Solutions
# Allian
# ----- Generating with diversity 0.5 seed: "ektrona
# Bu"
# ektrona
# Burging Capital
# Argent Press
# The Electronics
# Group
# Constream Solutions
# Vertera Sciences
# Telela Labs
# Th
# ----- Generating with diversity 1.0 seed: "ektrona
# Bu"
# ektrona
# BuylBush
# GolfSwittech
# Ahussy Talisco Internet Inc.
# Eachel Networks
# Acnont
# BrandUtecations & Supportint
# ----- Generating with diversity 1.2 seed: "ektrona
# Bu"
# ektrona
# Builde Firancial Idheom
# MFidy Technologies
# Mallet Metrics
# FUX quidn
# Coloncae Groveps Implay
# ILALL
# bour
#
#
# Epoch 6/10
#  - 54s - loss: 1.9175
#
# ----- Generating with diversity 0.2 seed: "ricula The"
# ricula Therapeutics
# Contect Corporation
# Stone Communications
# Care Star Communications
# Starther Communications
#
# ----- Generating with diversity 0.5 seed: "ricula The"
# ricula Therapeutics
# Tech Specialty Corporation
# Kanner Partners
# Elevers
# Stame Health Services
# Internet Health
# A
# ----- Generating with diversity 1.0 seed: "ricula The"
# ricula Therapeutics
# Instummenter
# PearuryInvestoralsBarels
# Godweetliere Privece
# Beshamaenex
# Bizean
# Global Cont.
# ----- Generating with diversity 1.2 seed: "ricula The"
# ricula Therapeutics
# Rbingyon
# Preseion Plarmanaationive
# FoungFap
# greakio
# FarmagjubYecox
# Amargo Systems
# 3D Mobil
#
#
# Epoch 7/10
#  - 54s - loss: 1.9083
#
# ----- Generating with diversity 0.2 seed: "ilano Exhi"
# ilano Exhinition
# Connect Solutions
# Social Solutions
# Starter Bank
# Starth Biosciences
# Constractive
# Constractive
#
# ----- Generating with diversity 0.5 seed: "ilano Exhi"
# ilano Exhinities
# Archano Publics
# Accelt Energy Services
# Popent Systems
# International
# Company
# Starterbook
# New I
# ----- Generating with diversity 1.0 seed: "ilano Exhi"
# ilano Exhinity fine Co.
# Agenta Securivies
# Outeource
# Reguulay ing
# Frelvand
# BRS Labs
# SchonoIoft
# Valback
# Onlrack
#
# ----- Generating with diversity 1.2 seed: "ilano Exhi"
# ilano Exhicare
# flua Corporation
# LIOM EMSYR For
# LymOlorsO, Inc.
# RESECANC.
# PaSaryamics
# Direct
# Cob
# pprietee.com
# N
#
#
# Epoch 8/10
#  - 54s - loss: 1.9007
#
# ----- Generating with diversity 0.2 seed: "NuView
# NuV"
# NuView
# NuVotec
# Accel Medical
# Conforet Solutions
# Source Solutions
# Company Systems
# Starthers
# Contection Systems
#
# ----- Generating with diversity 0.5 seed: "NuView
# NuV"
# NuView
# NuVision
# Lisking
# Moneture Group
# Autorators
# Techno Investment
# Jalitech Group
# Content Networks
# Maching Gr
# ----- Generating with diversity 1.0 seed: "NuView
# NuV"
# NuView
# NuVIO Solutions
# Homb
# Biota.com
# CyberSippib
# Sandis Intecle
# Desiverga Check
# Cardsecodia
# wide Share Enterp
# ----- Generating with diversity 1.2 seed: "NuView
# NuV"
# NuView
# NuVvix
# ATadlifcie Brewers
# Trappeston
# Arocaar
# La7ym
# ABA
# T urle Genesys
# CKL Crein4 Systems
# HKIALISEUECO L
#
#
# Epoch 9/10
#  - 54s - loss: 1.8949
#
# ----- Generating with diversity 0.2 seed: "work
# Scand"
# work
# Scander Company
# Group Studios
# Steel Company
# Allerity Services
# Senting Solutions
# Alling Company
# Carding Co
# ----- Generating with diversity 0.5 seed: "work
# Scand"
# work
# Scander Studio
# Manage Grid Company
# Penning
# Flashical Salution Simple Collections
# Gamerand Inc.
# Energient
# ----- Generating with diversity 1.0 seed: "work
# Scand"
# work
# Scanden Technologies
# T&T International
# WoBbe Electremoffucrorsh
# Daine
# Corla
# Unity
# Colentam
# CENES
# Eldo Cap
# ----- Generating with diversity 1.2 seed: "work
# Scand"
# work
# ScandGueDt Group
# Tavi Softwares
# Brigitx, Inc.
# Into
# GrastQiLO Design
# Gentros ChenerTechnologies
# MvIG
# ASTC)
#
#
# Epoch 10/10
#  - 56s - loss: 1.8905
#
# ----- Generating with diversity 0.2 seed: "
# Pringle T"
#
# Pringle Technology
# Single Properties
# Starther Ltd
# The Medical
# Marketing
# Alliance Services
# Starter Corporation
# ----- Generating with diversity 0.5 seed: "
# Pringle T"
#
# Pringle Technologies
# Bridge Energy
# Manage Pharmaceuticals
# American Systems
# Rock Solutions
# Accel Roin
# ShopQuar
# ----- Generating with diversity 1.0 seed: "
# Pringle T"
#
# Pringle Technologies
# Farmulion Devices
# Ehecuch Bank Consulting
# Allec
# Millings
# Attiam
# Nick LLC
# Keailp
# Imagen E
# ----- Generating with diversity 1.2 seed: "
# Pringle T"
#
# Pringle Technologies Solutions
# Na1styl
# Wipp Teck
# Bapfy Nuximent
# Fvaipoy
# Tellphea Auroysoft
# TeneSoupp
# lampara

# %%
def generate_text(length, diversity):
    # Get random name
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    for i in range(length):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char
    return sentence

# %%
g = re.sub("[\n ]", "", generate_text(5, .1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-482bd26d6c6b> in <module>
# ----> 1 g = re.sub("[\n ]", "", generate_text(5, .1))
#
# NameError: name 're' is not defined

# %%
import random

# %%
def generator(num):
    names = []
    for i in range(num):
        randnum = random.randint(0, 10)
        names.append(re.sub("[\n (){}?/,.<>:-]", "", generate_text(randnum, .1)))
    return names

# %%
names = generator(20)
for i in names:
    print(i)

# %%
model.save('newParas.h5')

# %%
print(len(text))

# %%
import pickle

# %%
with open('char_indices.pickle', 'wb') as out:
    pickle.dump(char_indices, out)
with open('indices_char.pickle', 'wb') as out:
    pickle.dump(indices_char, out)
