# %%
import pandas as pd
import numpy as np
from IPython.display import HTML

from __future__ import print_function
import keras
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, RNN, SimpleRNNCell, SimpleRNN
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
# !wget https://raw.githubusercontent.com/EliotAndres/char-rnn-tensorflow-js/master/python/companies.csv

# %%
companies = pd.read_csv('./companies.csv', header=None)
companies.head()
# Out:
#                     0
# 0       Hashplay Inc.
# 1      New Incentives
# 2            GrabJobs
# 3           MediBookr
# 4  MelissaWithLove.co

# %%
names = companies[0].values
text = '\n'.join(names)

chars = sorted(list(set(text)))
print('total chars: {}'.format(len(chars)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 150

# %%
print('Corpus length:', len(text), 'lines:', len(names))
print('First 10 lines:', names[:10])
print('Number of unique chars:', len(chars))
# Out:
# Corpus length: 2560407 lines: 172488
# First 10 lines: ['Hashplay Inc.' 'New Incentives' 'GrabJobs' 'MediBookr'
#  'MelissaWithLove.co' 'Starting 11' 'The CarShare Guy' 'Allahabad Bank'
#  'Anlaiye' 'Any Time Loan']
# Number of unique chars: 150

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 10
step = 3

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
print('First 10 sequences and next chars:')
for i in range(10):
    print('[{}]:[{}]'.format(sentences[i], next_chars[i]))
# Out:
# Number of sequences: 853466
# First 10 sequences and next chars:
# [Hashplay I]:[n]
# [hplay Inc.]:[
# ]
# [ay Inc.
# Ne]:[w]
# [Inc.
# New I]:[n]
# [.
# New Ince]:[n]
# [ew Incenti]:[v]
# [Incentives]:[
# ]
# [entives
# Gr]:[a]
# [ives
# GrabJ]:[o]
# [s
# GrabJobs]:[
# ]

# %%
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Size of X: {:.2f} MB'.format(X.nbytes/1024/1024))
print('Size of y: {:.2f} MB'.format(y.nbytes/1024/1024))
# Out:
# Vectorization...
# Size of X: 1220.89 MB
# Size of y: 122.09 MB

# %%
# ### Initialization
# 
# Now we are ready to create a recurrent model.  Keras contains three types of recurrent layers:
# 
#  * `SimpleRNN`, a fully-connected RNN where the output is fed back to input.
#  * `LSTM`, the Long-Short Term Memory unit layer.
#  * `GRU`, the Gated Recurrent Unit layer.
# 
# See https://keras.io/layers/recurrent/ for more information.

# Number of hidden units to use:
nb_units = 64

model = Sequential()

# Recurrent layers supported: SimpleRNN, LSTM, GRU:
model.add(LSTM(nb_units, input_shape=(maxlen, len(chars))))

# To stack multiple RNN layers, all RNN layers except the last one need
# to have "return_sequences=True".  An example of using two RNN layers:
#model.add(SimpleRNN(16,
#                    input_shape=(maxlen, len(chars)),
#                    return_sequences=True))
#model.add(SimpleRNN(32))

model.add(Dense(units=len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 64)                55040
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               9750
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# =================================================================
# Total params: 64,790
# Trainable params: 64,790
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
class SampleResult(keras.callbacks.Callback):

    def on_epoch_end(self, epoch, logs={}):

        start_index = random.randint(0, len(text) - maxlen - 1)

        for diversity in [0.2, 0.5, 1.0, 1.2]:
            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print()
            print('----- Generating with diversity',
                  diversity, 'seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(100):
                x = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x[0, t, char_indices[char]] = 1.

                preds = self.model.predict(x, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
        print('\n\n')
sample_callback = SampleResult()

# %%
history = model.fit(X, y, 
                        epochs=10, 
                        batch_size=512,
                        verbose=2,
                       callbacks=[sample_callback])
# Out:
# Epoch 1/10
#  - 47s - loss: 2.3009
#
# ----- Generating with diversity 0.2 seed: "ity Manufa"
# ity Manufacturing Solutions
# Connerge Corporation
# Conners Software
# Arder Limited
# Coners Solutions
# Solution Solu
# ----- Generating with diversity 0.5 seed: "ity Manufa"
# ity Manufacturing
# Group Book Energy
# Amersan Solutions
# Allight Stration Solutions
# Connovity Software
# Anter Inc.
# ----- Generating with diversity 1.0 seed: "ity Manufa"
# ity Manufacturn Motorance Corporaties Dealting
# mROPOEAD
# ChewillX
# Warghta Corporationt
# Streartlect Technologies
# ----- Generating with diversity 1.2 seed: "ity Manufa"
# ity Manufactduin
# FunnMopOllenc
# Expere
# N Grarsea Neturess) Ltd Ltu Biotpc, Inc
# ST Inteclecs.com
# MRR Indevt
# Port
#
#
# Epoch 2/10
#  - 42s - loss: 2.0286
#
# ----- Generating with diversity 0.2 seed: "y
# StackEng"
# y
# StackEngine
# Share Software
# Starment Development
# Sonicon Solutions
# Social Software
# Alliant Technologies
# South
# ----- Generating with diversity 0.5 seed: "y
# StackEng"
# y
# StackEngor
# Evelel Technology Corp
# Sead Limited
# Somichand Solutions
# Conternal Network
# International Partners
#
# ----- Generating with diversity 1.0 seed: "y
# StackEng"
# y
# StackEngoffinoam Transing
# North Stath
# Magon Hausting Health Setporats
# Mabkenter
# Hublen Enerria Rise Enogoms
#
# ----- Generating with diversity 1.2 seed: "y
# StackEng"
# y
# StackEng
# Lendle)
# Solach Mota Finatacyfrinder
# Albeen Data Therapmunications
# Orxicenson Lemige
# Gapbul
# Corred
# S
#
#
# Epoch 3/10
#  - 44s - loss: 1.9785
#
# ----- Generating with diversity 0.2 seed: "moor Servi"
# moor Services
# The Companies
# Artion Software Services
# Simple Company
# Comperic Corporation
# Propera
# Prostrate Com
# ----- Generating with diversity 0.5 seed: "moor Servi"
# moor Services
# Clouds International
# Procoble
# Wines.com
# Paring Partners
# Alis Componytics
# Floince
# Custers Service
# ----- Generating with diversity 1.0 seed: "moor Servi"
# moor Service
# Gasheleral
# Reologe
# Aremity
# R.Bibstering
# Idscrea
# Renterapartners
# Pethnerd
# Safetail
# Happ Olego
# Tica
# ----- Generating with diversity 1.2 seed: "moor Servi"
# moor Services, LLC
# IBD Yaw
# Rer Ghre,
# Macodrual
# TIN, Inc
# Inftwitement
# Iasy Technologies, Inc.
# duckE&S Creative
#
#
#
# Epoch 4/10
#  - 44s - loss: 1.9528
#
# ----- Generating with diversity 0.2 seed: "ts plc
# Pro"
# ts plc
# Propertive Solutions
# Digital Solutions
# Saller Consulting
# Silinity Corporation
# Alliance Services
# Service
# ----- Generating with diversity 0.5 seed: "ts plc
# Pro"
# ts plc
# Prostral Media
# Talia Intelligence
# Meliant Energy Partners
# Linebiller
# Concort Solutions
# Tonnel Consultin
# ----- Generating with diversity 1.0 seed: "ts plc
# Pro"
# ts plc
# Propeque
# Cliliques EJSYWE TV FINDETAT
# Pizapris
# Killar Vervis Network
# Rewicsers Owlite Graptive Healthca
# ----- Generating with diversity 1.2 seed: "ts plc
# Pro"
# ts plc
# Provigo
# Recrover.iehe Reckwer Technology Groatics powenic ity)
# Dimitiny, Bazce Integrast
# Piptumbli
# inin
#
#
# Epoch 5/10
#  - 44s - loss: 1.9363
#
# ----- Generating with diversity 0.2 seed: "se Media S"
# se Media Services
# Star Communications
# Stream Strategics
# Service Solutions
# Starther Solutions
# Carter Studios
# St
# ----- Generating with diversity 0.5 seed: "se Media S"
# se Media Systems
# Student
# Shang Pet Technologies
# Stemple Software
# Accel Capital
# Ellas Performent Services
# Teles
# ----- Generating with diversity 1.0 seed: "se Media S"
# se Media Services Ltd.
# Spriny Media
# Hosdica
# raie Capital
# INDDEY CONDIR
# Blo Incents
# Touch Service
# Vendoria
# OMAY
# ----- Generating with diversity 1.2 seed: "se Media S"
# se Media Sparis.comm
# DluckssSciences
# Graphachline
# Zef Numois
# Con Candlo
# Outnitries
# Wore
# Adma Mobprite Business
#
#
# Epoch 6/10
#  - 44s - loss: 1.9251
#
# ----- Generating with diversity 0.2 seed: "systems
# Co"
# systems
# Contract Corporation
# Singer Company
# Mondor Company
# Digital Corporation
# Soline Solutions
# Market Solutio
# ----- Generating with diversity 0.5 seed: "systems
# Co"
# systems
# Congal Sports
# The Tech Medical
# Manan Consulting
# Transpresting Services
# Tech Technologies
# PVI Consultin
# ----- Generating with diversity 1.0 seed: "systems
# Co"
# systems
# Cortrako Way Hotel Malartind Stateling
# Apitex Investory Lacssine Science
# Reathy Reaka
# Fatada Focfs
# Oye
# ----- Generating with diversity 1.2 seed: "systems
# Co"
# systems
# Conscustem
# Pharmand Blorsified
# iT-eish Denters
# BTRE LT.T)
# MWP Logistics
# GeneAccel Group
# Koning Teleter
#
#
# Epoch 7/10
#  - 42s - loss: 1.9167
#
# ----- Generating with diversity 0.2 seed: "braryThing"
# braryThing
# Solar Stars
# Alliance Services
# Solar Star Services
# Star Technologies
# Contronce Services
# Star Star So
# ----- Generating with diversity 0.5 seed: "braryThing"
# braryThing Inc.
# Holl State Systems
# Medical Inc.
# Spiel Storage (Insparnet Services
# Micro Holdings
# Callation Com
# ----- Generating with diversity 1.0 seed: "braryThing"
# braryThing
# Contrium Group
# Kappick
# Moves Reegrobrave
# Mut Hoca Mottore
# HighSolutions
# KTB & AF
#  Softwiters
# Aferfe
# ----- Generating with diversity 1.2 seed: "braryThing"
# braryThingFiD
# Procud TSieti
# Elligrogon Collectium
# ICE
# Moromod Jefformowital
# Pussapp
# DwandCheb
# CloodeCaly Land
#
#
#
# Epoch 8/10
#  - 42s - loss: 1.9099
#
# ----- Generating with diversity 0.2 seed: "Heritage B"
# Heritage Bank
# Corporation
# Connect
# Alliant Solutions
# State Corporation
# The Corporation
# Alliance Corporation
# Con
# ----- Generating with diversity 0.5 seed: "Heritage B"
# Heritage Bank
# Spring Technologies
# Information Group
# RightCare
# Powerwire
# Xtremactica
# Rights Corporation
# Snapens
# ----- Generating with diversity 1.0 seed: "Heritage B"
# Heritage Bank
# Tech Energice
# Fortmithe
# Drandvernics
# Glimpeth
# LLLIX
# Alix Industries
# Orcaal Alectione Services
# Sy
# ----- Generating with diversity 1.2 seed: "Heritage B"
# Heritage BeneWeat Talligon
# TelNations
# Koto Thome
# Kebx
# LCP
# Qunetsu
# SBXC Theropy Technologies Capital
# EVS Corpor
#
#
# Epoch 9/10
#  - 43s - loss: 1.9052
#
# ----- Generating with diversity 0.2 seed: "rrow
# urban"
# rrow
# urban
# The Constructs
# Controller
# Canning Solutions
# Applical Solutions
# Alliance Corporation
# Alliance Partne
# ----- Generating with diversity 0.5 seed: "rrow
# urban"
# rrow
# urbanco Solutions
# Appolia
# Go International Solutions
# Gold Insurance Group
# Exchelonics
# Grainicon - Solutio
# ----- Generating with diversity 1.0 seed: "rrow
# urban"
# rrow
# urbangely
# Twine.com
# Evellet Biopheumi
# MOMALA. Culters
# Outmertech
# Someq, Inc
# Insolicaler
# AigLibo
# eLioner A
# ----- Generating with diversity 1.2 seed: "rrow
# urban"
# rrow
# urbanghix
# Solondesies S.A.
# Uniwne Pos
# Reacon Group
# MRH Italiam
# MXSL
# FBelop Healtherment Regecheperi
# UB Le
#
#
# Epoch 10/10
#  - 42s - loss: 1.9012
#
# ----- Generating with diversity 0.2 seed: "nnector Sy"
# nnector Systems
# Starter Company
# Star Company
# Entertica
# Star Company
# Accel Services
# Controls Solutions
# Star Tec
# ----- Generating with diversity 0.5 seed: "nnector Sy"
# nnector Systems
# Retail
# Metal Media
# Innovations
# Pender Publications
# Biostar Recovery
# Retalet
# Caron Insurance
# Ac
# ----- Generating with diversity 1.0 seed: "nnector Sy"
# nnector System
# daymeke Siffice-Clouds
# ziscer
# SaterMobile
# 48
# Coarunia
# Tattix
# iGoce Anvia
# URBOPA EG
# Squarge
# Maut
# ----- Generating with diversity 1.2 seed: "nnector Sy"
# nnector Systems
# Ivugu INILA. Brups
# CayFables
# Invirra Corp Inc.
# Wikikzu Limimegis Marketolione
# MovaMar BioVetio

# %%
def generate_text(length, diversity):
    # Get random name
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    for i in range(length):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char
    return sentence

# %%
g = re.sub("[\n ]", "", generate_text(5, .1))

# %%
import random

# %%
def generator(num):
    names = []
    for i in range(num):
        randnum = random.randint(0, 10)
        names.append(re.sub("[\n (){}?/,.<>:-]", "", generate_text(randnum, .1)))
    return names

# %%
names = generator(20)
for i in names:
    print(i)
# Out:
# rsCompani
# tranSolut
# lWinderS
# esPortal
# veAirbor
# SciencesS
# entricaCo
# ntContegr
# enceAFIS
# oEveronS
# ainability
# otMinting
# DriveStre
# ServicesS
# echnology
# aAzalenS
# syknaSolu
# rServices
# mpanyStar
# viceBank

# %%
print(len(text))
# Out:
# 2560407

# %%
import pickle

# %%
with open('char_indices.pickle', 'wb') as out:
    pickle.dump(char_indices, out)
with open('indices_char.pickle', 'wb') as out:
    pickle.dump(indices_char, out)
